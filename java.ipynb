# %% [markdown]
# <a href="https://colab.research.google.com/github/kudupudimeghana/Afforestation_impact_modelling/blob/main/java.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install openjdk-17-jdk-headless -qq > /dev/null

# %%
# %%writefile Hello.java
# public class Hello {
#     public static void main(String[] args) {
#         System.out.println("Hello Maggie!");
#     }
# }
# Out:
# Writing Hello.java

# %%
# !javac Hello.java

# %%
# !java Hello
# Out:
# Hello Maggie!
